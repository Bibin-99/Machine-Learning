# %% [markdown]
# # FINANCE

# %% [markdown]
# ### The finance dataset consists of 100 records with seven numerical columns labeled X1 to X6 as independent variables and Y as the target variable.X1 - Market Volatility Index (VIX): Measures the expected market fluctuations. X2 - Interest Rate (%): Represents central bank interest rates impacting investments. X3 - Inflation Rate (%): Affects purchasing power and investment decisions. X4 - Stock Price Momentum: Measures recent stock trends and performance. X5 - Credit Risk Score: Indicates the risk level of financial assets. X6 - Economic Growth Rate (GDP %): Represents the overall economic condition. Y - Investment Return (%): The target variable representing financial returns based on the above factors. The dataset likely represents financial metrics, economic indicators, or investment-related data, where Y could be a dependent variable such as revenue, profit, or risk assessment.

# %% [markdown]
# # IMPORTING LIBRARIES AND DATASET

# %%
import numpy as np
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
df = pd.read_csv(r"E:\Data Anaiytics\Work space\Project\ML\Ploynomial\finance.csv")

# %% [markdown]
# # ANALYZING OF FIRST 20 DATA

# %%
print(df.head(20))
# Out:
#           X1        X2        X3        X4        X5        X6           Y
# 0  -2.509198  9.014286  4.639879  1.973170 -6.879627 -6.880110  -11.234777
# 1  -8.838328  7.323523  2.022300  4.161452 -9.588310  9.398197 -488.437562
# 2   6.648853 -5.753218 -6.363501 -6.331910 -3.915155  0.495129   52.984166
# 3  -1.361100 -4.175417  2.237058 -7.210123 -4.157107 -2.672763   -0.490722
# 4  -0.878600  5.703519 -6.006524  0.284689  1.848291 -9.070992   80.150935
# 5   2.150897 -6.589518 -8.698968  8.977711  9.312641  6.167947 -524.768605
# 6  -3.907725 -8.046558  3.684661 -1.196950 -7.559235 -0.096462  116.699334
# 7  -9.312230  8.186408 -4.824400  3.250446 -3.765778  0.401360  -88.262437
# 8   0.934206 -6.302911  9.391693  5.502656  8.789979  7.896547  -73.097598
# 9   1.958000  8.437485 -8.230150 -6.080343 -9.095454 -3.493393    7.335147
# 10 -2.226454 -4.573019  6.574750 -2.864933 -4.381310  0.853922    0.711577
# ...

# %% [markdown]
# # ANALYZING OF LAST 20 DATA

# %%
print(df.tail(20))
# Out:
#           X1        X2        X3        X4        X5        X6           Y
# 80  2.587973  3.914974 -0.909179  2.551162  1.686286  8.023160  -40.507484
# 81 -9.091072 -4.380736  9.008230  7.805276 -0.886865  2.402652 -254.141143
# 82 -4.452376 -6.237577 -0.726032 -2.932955  1.673122 -8.445307  -42.386535
# 83  9.487896  9.724215  3.963234  0.721927 -3.809448  6.275900 -252.281560
# 84  3.694623 -6.747661  8.218544  6.450745  8.995998  4.514390  -95.433278
# 85  2.268304 -1.635139  8.654570  7.321278 -9.095627 -9.472661   12.644828
# 86 -2.470733  6.211067  9.745523 -6.991662  1.882614 -2.382183 -247.112006
# 87  9.398288  6.842378  6.766574 -0.626137 -1.703610 -4.531859 -239.134044
# 88 -8.872490  7.294448  6.258020  9.994353  9.932737  1.108634  127.881411
# 89  5.379748  8.895315  6.992948 -5.053038 -0.989117 -7.416812 -230.328815
# 90  9.081021  2.123493 -5.427144  3.434014  2.362565 -2.836746 -223.505092
# ...

# %% [markdown]
# # INFORMATION ABOUT THE DATASET

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      100 non-null    float64
#  1   X2      100 non-null    float64
#  2   X3      100 non-null    float64
#  3   X4      100 non-null    float64
#  4   X5      100 non-null    float64
#  5   X6      100 non-null    float64
#  6   Y       100 non-null    float64
# dtypes: float64(7)
# memory usage: 5.6 KB
# None

# %% [markdown]
# # CHECKING FOR NULL VALUE

# %%
print(df.isna().sum())
# Out:
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# Y     0
# dtype: int64

# %% [markdown]
# # CLEANING EMPTY CELLS

# %%
df.dropna(inplace=True)

# %% [markdown]
# # STATISTICAL ANALYSIS

# %% [markdown]
# ### COVARIANCE

# %%
print(df.cov(numeric_only=True))
# Out:
#             X1         X2         X3         X4         X5          X6  \
# X1   35.659143   1.524451  -0.730196  -0.354530  -5.965060    2.920425
# X2    1.524451  33.271619   1.549665  -3.366518  -2.019113   -1.306597
# X3   -0.730196   1.549665  37.964580   1.774424  -1.521322   -1.255110
# X4   -0.354530  -3.366518   1.774424  32.802663   3.948177    3.401682
# X5   -5.965060  -2.019113  -1.521322   3.948177  37.597092    1.618128
# X6    2.920425  -1.306597  -1.255110   3.401682   1.618128   35.544425
# Y  -276.700941 -42.884423 -74.962338 -12.072104  28.217965 -206.499072
#
#                Y
# X1   -276.700941
# X2    -42.884423
# X3    -74.962338
# X4    -12.072104
# X5     28.217965
# X6   -206.499072
# Y   28221.339444

# %% [markdown]
# ### CORRELATION

# %%
correlation=df.corr(numeric_only=True)
print(correlation)
# Out:
#           X1        X2        X3        X4        X5        X6         Y
# X1  1.000000  0.044258 -0.019846 -0.010366 -0.162912  0.082030 -0.275827
# X2  0.044258  1.000000  0.043603 -0.101904 -0.057088 -0.037994 -0.044256
# X3 -0.019846  0.043603  1.000000  0.050282 -0.040268 -0.034167 -0.072421
# X4 -0.010366 -0.101904  0.050282  1.000000  0.112426  0.099622 -0.012547
# X5 -0.162912 -0.057088 -0.040268  0.112426  1.000000  0.044264  0.027394
# X6  0.082030 -0.037994 -0.034167  0.099622  0.044264  1.000000 -0.206179
# Y  -0.275827 -0.044256 -0.072421 -0.012547  0.027394 -0.206179  1.000000

# %% [markdown]
# # HEATMAP

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # BOXPLOT

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.xticks(rotation=45)
plt.title("Boxplot of Dataset Variables")
plt.show()

# %% [markdown]
# # DESCRIBE

# %%
stats=df.describe()
print(stats)
# Out:
#                X1          X2          X3          X4          X5          X6  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.121680    1.298240    0.099726    0.107601   -0.460451   -0.804630
# std      5.971528    5.768156    6.161540    5.727361    6.131647    5.961915
# min     -9.889558   -9.816059   -9.860957   -9.668243   -9.898768   -9.783247
# 25%     -4.340487   -3.571043   -5.292223   -5.130894   -6.206264   -6.086672
# 50%      0.390332    2.264842    0.702857    0.503308   -0.937991   -0.543133
# 75%      5.865162    6.102781    5.261743    4.568281    4.519792    4.173882
# max      9.810103    9.859296    9.745523    9.994353    9.932737    9.600652
#
#                 Y
# count  100.000000
# mean   -79.505469
# std    167.992081
# min   -545.876308
# 25%   -176.763682
# 50%    -54.846482
# 75%     39.612883
# max    305.137530

# %% [markdown]
# # SCATTERPLOT

# %%
plt.figure(figsize=(12, 8))
for column in df.columns[:-1]:  # Exclude the target variable Y
    plt.scatter(df[column], df["Y"], label=column, alpha=0.5)
plt.xlabel("Features")
plt.ylabel("Y")
plt.title("Scatterplot of Features vs. Target Variable")
plt.legend()
plt.show()

# %%
print(df.to_string())
# Out:
#           X1        X2        X3        X4        X5        X6           Y
# 0  -2.509198  9.014286  4.639879  1.973170 -6.879627 -6.880110  -11.234777
# 1  -8.838328  7.323523  2.022300  4.161452 -9.588310  9.398197 -488.437562
# 2   6.648853 -5.753218 -6.363501 -6.331910 -3.915155  0.495129   52.984166
# 3  -1.361100 -4.175417  2.237058 -7.210123 -4.157107 -2.672763   -0.490722
# 4  -0.878600  5.703519 -6.006524  0.284689  1.848291 -9.070992   80.150935
# 5   2.150897 -6.589518 -8.698968  8.977711  9.312641  6.167947 -524.768605
# 6  -3.907725 -8.046558  3.684661 -1.196950 -7.559235 -0.096462  116.699334
# 7  -9.312230  8.186408 -4.824400  3.250446 -3.765778  0.401360  -88.262437
# 8   0.934206 -6.302911  9.391693  5.502656  8.789979  7.896547  -73.097598
# 9   1.958000  8.437485 -8.230150 -6.080343 -9.095454 -3.493393    7.335147
# 10 -2.226454 -4.573019  6.574750 -2.864933 -4.381310  0.853922    0.711577
# ...

# %%
x=df.iloc[:, :-1].values
y=df.iloc[: ,1].values

# %% [markdown]
# # Split into features (X) and target variable (Y)

# %%
X = df.drop(columns=["Y"])
Y = df["Y"]

# %% [markdown]
# # Split data into training (80%) and testing (20%) sets

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# # Apply Polynomial Features transformation (degree=2)

# %%
poly = PolynomialFeatures(degree=2, include_bias=False)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# %% [markdown]
# # Train the Polynomial Regression Model

# %%
model = LinearRegression()
model.fit(X_train_poly, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Predictions

# %%
Y_train_pred = model.predict(X_train_poly)
Y_test_pred = model.predict(X_test_poly)

# %% [markdown]
# # Evaluate model performance

# %%
r2_train = r2_score(Y_train, Y_train_pred)
r2_test = r2_score(Y_test, Y_test_pred)

# %% [markdown]
# # Print results

# %%
print(f"Training R² Score: {r2_train:.4f}")
print(f"Testing R² Score: {r2_test:.4f}")
# Out:
# Training R² Score: 0.9994
# Testing R² Score: 0.9982

# %% [markdown]
# # SUMMARY

# %% [markdown]
# ### The dataset contains 100 entries with 7 numerical columns (X1 to X6 as independent variables and Y as the dependent variable). All columns contain float values with no missing data. This dataset is likely used for financial modeling or regression analysis. The dataset consists of six independent variables (X1 to X6) and one dependent variable (Y), with all independent variables having a mean close to zero and values ranging between approximately -10 and 10. The dependent variable (Y) has a much wider range from -545.88 to 305.14, with a mean of -79.51 and a high standard deviation of 167.99, indicating considerable variability. Histograms and pairplot visualizations suggest that X1 to X6 follow roughly normal distributions, while Y shows a broad range with potential outliers and possible correlations with some independent variables.

# %% [markdown]
# # LAPTOP SHOP

# %% [markdown]
# ### This synthetic laptop dataset consists of 500 entries, each representing a laptop's key specifications and its corresponding price. The dataset includes seven columns: six features and one target variable, "Price_$(USD)." The features are designed to reflect common specifications that influence a laptop's price: processor speed (GHz), RAM size (GB), storage capacity (GB), screen size (inches), battery life (hours), and weight (kg). These features cover a range of realistic values, capturing variations in performance, design, and functionality typically found in laptops. Noise has been introduced to the data to simulate real-world pricing variability.

# %% [markdown]
# # IMPORTING LIBRARIES AND DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('E:\Data Anaiytics\Work space\Project\ML\Classification\Logistic regression\laptop_dataset.csv')

# %% [markdown]
# # ANALYZING OF FIRST 20 DATA

# %%
print(df.head(20))
# Out:
#     Processor_Speed_GHz  RAM_GB  Storage_GB  Screen_Size_Inches  \
# 0              2.810890       8        1024           13.740532
# 1              4.827500      16         512           15.167604
# 2              4.061979       4         512           16.491783
# 3              3.595305       4        1024           15.928900
# 4              2.046065       4        1024           16.226245
# 5              2.045981       4        1024           15.635133
# 6              1.703293      32        2048           15.769106
# 7              4.531617       4         512           16.396783
# 8              3.603903      32        2048           13.998672
# 9              3.978254      32        2048           14.957700
# 10             1.572046       4        1024           13.884838
# 11             4.894684       4        1024           16.950672
# 12             4.413549       8         256           16.776237
# 13             2.243187      16         256           13.157707
# ...

# %% [markdown]
# # ANALYZING OF LAST 20 DATA

# %%
print(df.tail(20))
# Out:
#      Processor_Speed_GHz  RAM_GB  Storage_GB  Screen_Size_Inches  \
# 480             3.702895      16         256           16.271337
# 481             3.935120       4        2048           13.480836
# 482             3.090894       8        2048           15.177956
# 483             3.696453       4        1024           13.023035
# 484             3.545100      16         512           14.298343
# 485             4.654053      16         512           14.465846
# 486             1.659062      16         512           14.584691
# 487             2.483371       4        2048           15.781869
# 488             4.826440       4        1024           14.554232
# 489             4.615923       4         256           14.794774
# 490             3.094799       4        2048           13.950177
# 491             3.670464      16        1024           14.493007
# 492             2.470834      16        1024           13.909079
# ...

# %% [markdown]
# # INFORMATION ABOUT THE DATASET

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Processor_Speed_GHz  500 non-null    float64
#  1   RAM_GB               500 non-null    int64
#  2   Storage_GB           500 non-null    int64
#  3   Screen_Size_Inches   500 non-null    float64
#  4   Battery_Life_Hours   500 non-null    float64
#  5   Weight_Kg            500 non-null    float64
#  6   Price_$              500 non-null    float64
# dtypes: float64(5), int64(2)
# memory usage: 27.5 KB
# None

# %% [markdown]
# # CHECKING FOR NULL VALUE

# %%
df.isna().sum()
# Out:
# Processor_Speed_GHz    0
# RAM_GB                 0
# Storage_GB             0
# Screen_Size_Inches     0
# Battery_Life_Hours     0
# Weight_Kg              0
# Price_$                0
# dtype: int64

# %% [markdown]
# # CLEANING EMPTY CELLS

# %%
df.dropna(inplace=True)

# %% [markdown]
# # STATISTICAL ANALYSIS

# %% [markdown]
# ### COVARIANCE

# %%
print(df.cov(numeric_only=True))
# Out:
#                      Processor_Speed_GHz       RAM_GB     Storage_GB  \
# Processor_Speed_GHz             1.092881     0.260034     -30.004078
# RAM_GB                          0.260034   103.619976      52.812954
# Storage_GB                    -30.004078    52.812954  441455.486717
# Screen_Size_Inches              0.067066     0.651323     -55.928580
# Battery_Life_Hours             -0.039323     0.583966      34.161439
# Weight_Kg                       0.003287     0.040973     -12.042292
# Price_$                       324.294428  5361.018378  206789.248607
#
#                      Screen_Size_Inches  Battery_Life_Hours  Weight_Kg  \
# Processor_Speed_GHz            0.067066           -0.039323   0.003287
# RAM_GB                         0.651323            0.583966   0.040973
# Storage_GB                   -55.928580           34.161439 -12.042292
# Screen_Size_Inches             1.413178            0.016037   0.087808
# ...

# %% [markdown]
# ### CORRELATION

# %%
correlation=df.corr(numeric_only=True)
print(correlation)
# Out:
#                      Processor_Speed_GHz    RAM_GB  Storage_GB  \
# Processor_Speed_GHz             1.000000  0.024436   -0.043197
# RAM_GB                          0.024436  1.000000    0.007809
# Storage_GB                     -0.043197  0.007809    1.000000
# Screen_Size_Inches              0.053966  0.053824   -0.070810
# Battery_Life_Hours             -0.014562  0.022209    0.019905
# Weight_Kg                       0.004400  0.005633   -0.025366
# Price_$                         0.437449  0.742677    0.438894
#
#                      Screen_Size_Inches  Battery_Life_Hours  Weight_Kg  \
# Processor_Speed_GHz            0.053966           -0.014562   0.004400
# RAM_GB                         0.053824            0.022209   0.005633
# Storage_GB                    -0.070810            0.019905  -0.025366
# Screen_Size_Inches             1.000000            0.005223   0.103376
# Battery_Life_Hours             0.005223            1.000000   0.000256
# ...

# %% [markdown]
# # BOXPLOT

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(15, 8))
sns.boxplot(data=df, orient="h", palette="muted")
plt.title("Boxplot of Laptop Dataset Features", fontsize=16)
plt.xlabel("Value Range", fontsize=14)
plt.ylabel("Features", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # HEATMAP

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # DESCRIBE

# %%
stats=df.describe()
print(stats)
# Out:
#        Processor_Speed_GHz     RAM_GB   Storage_GB  Screen_Size_Inches  \
# count           500.000000  500.00000   500.000000          500.000000
# mean              3.244966   13.79200   918.016000           15.070232
# std               1.045409   10.17939   664.421167            1.188772
# min               1.517716    4.00000   256.000000           13.019760
# 25%               2.344479    4.00000   256.000000           13.964912
# 50%               3.296073    8.00000   512.000000           15.158953
# 75%               4.146437   16.00000  1024.000000           16.109375
# max               4.975377   32.00000  2048.000000           16.997655
#
#        Battery_Life_Hours   Weight_Kg      Price_$
# count          500.000000  500.000000   500.000000
# mean             7.468288    2.249609  3814.485318
# std              2.583089    0.714523   709.129162
# min              3.028964    1.003913  2171.390335
# 25%              5.169668    1.670280  3293.000639
# ...

# %% [markdown]
# # SCATTERPLOT

# %%
# Define columns for the scatter plot
x_column = 'RAM_GB'
y_column = 'Price_$'

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df[x_column], df[y_column], alpha=0.7, edgecolor='k')
plt.title(f'Scatter Plot of {y_column} vs. {x_column}', fontsize=14)
plt.xlabel(x_column, fontsize=12)
plt.ylabel(y_column, fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
print(df.to_string())
# Out:
#      Processor_Speed_GHz  RAM_GB  Storage_GB  Screen_Size_Inches  Battery_Life_Hours  Weight_Kg      Price_$
# 0               2.810890       8        1024           13.740532            7.671736   1.654264  3405.588771
# 1               4.827500      16         512           15.167604            7.312637   1.617447  4297.165085
# 2               4.061979       4         512           16.491783            3.230779   3.265636  3345.281741
# 3               3.595305       4        1024           15.928900            6.071230   1.623865  3554.095374
# 4               2.046065       4        1024           16.226245            6.421761   1.679874  3101.586897
# 5               2.045981       4        1024           15.635133            6.589405   2.898496  2992.831683
# 6               1.703293      32        2048           15.769106            8.221551   2.124350  4915.052163
# 7               4.531617       4         512           16.396783            7.802423   2.941776  3733.548321
# ...

# %%
x=df.iloc[:, :-1].values
y=df.iloc[: ,1].values

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
median_price = df['Price_$'].median()
df['High_Price'] = (df['Price_$'] > median_price).astype(int)

# %% [markdown]
# # Split the dataset into features (X) and target (y)

# %%
X = df.drop(columns=["Price_$"])
y = df["Price_$"]

# %% [markdown]
# ### Split dataset into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# #  Initialize and train the Linear Regression model

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Make predictions

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ### Evaluate the model

# %%
mse = mean_squared_error(y_test, y_pred)  # Mean Squared Error
r2 = r2_score(y_test, y_pred)  # R-squared score

# %% [markdown]
# ### Output results

# %%
print("Mean Squared Error (MSE):", mse)
print("R-squared Score (R2):", r2)
# Out:
# Mean Squared Error (MSE): 8316.16812972335
# R-squared Score (R2): 0.9805276898571893

# %% [markdown]
# # SUMMARY

# %% [markdown]
# ### The dataset contains 500 entries with 7 numerical attributes related to laptops: Processor_Speed_GHz, RAM_GB, Storage_GB, Screen_Size_Inches, Battery_Life_Hours, Weight_Kg, and Price_$. All columns have complete data with no missing values. The dataset includes specifications such as processor speed, RAM size, storage capacity, screen size, battery life, weight, and price. I will now generate summary statistics and visualizations to highlight key insights.
# ### The dataset shows that laptops have an average processor speed of 3.24 GHz, RAM between 4GB and 32GB, storage ranging from 256GB to 2TB, and an average screen size of 15 inches. Battery life varies from 3 to 12 hours, weight ranges from 1kg to 3.5kg, and prices average $3,814, with a minimum of $2,171 and a maximum of $5,899. The visualizations reveal trends between price and specifications, such as processor speed, RAM, storage, battery life, and weight.

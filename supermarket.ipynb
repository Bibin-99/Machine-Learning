# %% [markdown]
# # SUPER MARKET DATASET

# %% [markdown]
# ### The supermarket dataset provides insights into sales transactions, customer behavior, and product trends. It likely includes key attributes such as product categories, sales amounts, transaction dates, customer demographics, and payment methods. This dataset can be used for analyzing sales performance, identifying popular products, understanding customer purchasing patterns, and optimizing inventory management. By exploring these attributes, businesses can make data-driven decisions to improve revenue, enhance customer experience, and streamline operations.

# %% [markdown]
# # IMPORTING LIBRARIES AND DATASET

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
df=pd.read_excel('E:\Data Anaiytics\Work space\Project\ML\Ploynomial\supermarket.xlsx')

# %% [markdown]
# # ANALYZING OF FIRST 20 DATA

# %%
print(df.head(20))
# Out:
#     Advertising_Budget  Store_Size  Competitor_Stores  Customer_Income  \
# 0            38.079472   35.209924           2.666196       260.021811
# 1            95.120716   27.268722           5.877109       240.111757
# 2            73.467400   16.166853           8.856513        13.795391
# 3            60.267190   40.875956           7.590024       171.282666
# 4            16.445845   34.551827           8.259050       190.717614
# 5            16.443458    8.968230           6.929050       200.012568
# 6             6.750278   45.635432           7.230489       290.506012
# 7            86.751438   41.304325           8.642761       267.267671
# 8            60.510386   47.540196           3.247012       304.344641
# 9            71.099185   36.560256           5.404825       382.676748
# 10            3.037865   31.057345           2.990885       406.679884
# 11           97.021075   21.493909           9.889012       359.343415
# ...

# %% [markdown]
# # ANALYZING OF LAST 20 DATA

# %%
print(df.tail(20))
# Out:
#      Advertising_Budget  Store_Size  Competitor_Stores  Customer_Income  \
# 480           63.310465   17.377951           8.360508        93.864608
# 481           69.879120   38.774698           2.081881       401.519012
# 482           45.999565    6.223314           5.900402       229.635256
# 483           63.128250    4.681751           1.051828       242.001467
# 484           58.847117   36.681249           3.921272        67.606506
# 485           90.214643   25.279074           4.298154        41.220155
# 486            5.499192   34.731717           4.565554       364.241714
# 487           28.815356   22.306540           7.259205       248.734115
# 488           95.090737   13.073700           4.497023       218.988501
# 489           89.136115   41.136014           5.038243       365.024606
# 490           46.110019   40.171378           3.137897       382.990937
# 491           62.393127   35.040127           4.359266        80.295176
# ...

# %% [markdown]
# # INFORMATION ABOUT THE DATASET

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Advertising_Budget  500 non-null    float64
#  1   Store_Size          500 non-null    float64
#  2   Competitor_Stores   500 non-null    float64
#  3   Customer_Income     500 non-null    float64
#  4   Promotions          500 non-null    float64
#  5   Month               500 non-null    float64
#  6   Sales               500 non-null    float64
# dtypes: float64(7)
# memory usage: 27.5 KB
# None

# %% [markdown]
# # CHECKING FOR NULL VALUE

# %%
df.isna().sum()
# Out:
# Advertising_Budget    0
# Store_Size            0
# Competitor_Stores     0
# Customer_Income       0
# Promotions            0
# Month                 0
# Sales                 0
# dtype: int64

# %% [markdown]
# # CLEANING EMPTY CELLS

# %%
df.dropna(inplace=True)

# %% [markdown]
# # STATISTICAL ANALYSIS

# %% [markdown]
# ### COVARIANCE

# %%
print(df.cov(numeric_only=True))
# Out:
#                     Advertising_Budget   Store_Size  Competitor_Stores  \
# Advertising_Budget          874.393915     4.283142           4.268268
# Store_Size                    4.283142   195.697140          -0.969570
# Competitor_Stores             4.268268    -0.969570           7.154215
# Customer_Income             -61.670177     1.048227           2.000613
# Promotions                    0.706610    -2.089522           1.501521
# Month                        -0.351357     1.150795           0.412650
# Sales                     43701.646915 -3088.951228         358.919210
#
#                     Customer_Income  Promotions       Month         Sales
# Advertising_Budget       -61.670177    0.706610   -0.351357  4.370165e+04
# Store_Size                 1.048227   -2.089522    1.150795 -3.088951e+03
# Competitor_Stores          2.000613    1.501521    0.412650  3.589192e+02
# Customer_Income        20511.372064    0.199415  -22.456416  2.219252e+04
# ...

# %% [markdown]
# ### CORRELATION

# %%
correlation=df.corr(numeric_only=True)
print(correlation)
# Out:
#                     Advertising_Budget  Store_Size  Competitor_Stores  \
# Advertising_Budget            1.000000    0.010354           0.053966
# Store_Size                    0.010354    1.000000          -0.025912
# Competitor_Stores             0.053966   -0.025912           1.000000
# Customer_Income              -0.014562    0.000523           0.005223
# Promotions                    0.004400   -0.027506           0.103376
# Month                        -0.003653    0.025289           0.047427
# Sales                         0.940509   -0.140520           0.085395
#
#                     Customer_Income  Promotions     Month     Sales
# Advertising_Budget        -0.014562    0.004400 -0.003653  0.940509
# Store_Size                 0.000523   -0.027506  0.025289 -0.140520
# Competitor_Stores          0.005223    0.103376  0.047427  0.085395
# Customer_Income            1.000000    0.000256 -0.048202  0.098612
# ...

# %% [markdown]
# # BOXPLOT

# %%
columns_to_plot = [
    'Advertising_Budget',
    'Store_Size',
    'Competitor_Stores',
    'Customer_Income',
    'Promotions',
    'Month',
    'Sales'
]
plt.figure(figsize=(12, 6))
df[columns_to_plot].boxplot()
plt.title("Boxplot of Supermarket Dataset Variables")
plt.ylabel("Values")
plt.xlabel("Features")
plt.xticks(rotation=45)
plt.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# # HEATMAP

# %%
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # DESCRIBE

# %%
stats=df.describe()
print(stats)
# Out:
#        Advertising_Budget  Store_Size  Competitor_Stores  Customer_Income  \
# count          500.000000  500.000000         500.000000       500.000000
# mean            50.357610   24.615618           5.658023       248.741768
# std             29.570152   13.989179           2.674736       143.217918
# min              1.501097    1.226969           1.044460         2.605914
# 25%             24.886689   12.225863           3.171052       121.296061
# 50%             51.803211   24.119257           5.857645       254.936777
# 75%             75.856363   36.590504           7.996094       368.950749
# max             99.303515   49.986166           9.994724       499.175408
#
#        Promotions       Month        Sales
# count  500.000000  500.000000   500.000000
# mean    10.497029    6.554646  1691.383170
# std      5.430374    3.252956  1571.379595
# min      1.029737    1.000128  -735.151627
# 25%      6.094132    3.857956   385.682445
# ...

# %% [markdown]
# # SCATTERPLOT

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Advertising_Budget'], df['Sales'], alpha=0.7, color='blue', edgecolor='k')
plt.title("Scatter Plot of Advertising Budget vs. Sales")
plt.xlabel("Advertising Budget ($1000s)")
plt.ylabel("Sales")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print(df.to_string())
# Out:
#      Advertising_Budget  Store_Size  Competitor_Stores  Customer_Income  Promotions      Month        Sales
# 0             38.079472   35.209924           2.666196       260.021811    5.972408  10.102708   463.497127
# 1             95.120716   27.268722           5.877109       240.111757    5.692597   9.409806  4394.403938
# 2             73.467400   16.166853           8.856513        13.795391   18.218837   7.308818  2703.437159
# 3             60.267190   40.875956           7.590024       171.282666    5.741378  11.516519  1036.250652
# 4             16.445845   34.551827           8.259050       190.717614    6.167045   3.205220    75.827465
# 5             16.443458    8.968230           6.929050       200.012568   15.428567   2.201906   507.503645
# 6              6.750278   45.635432           7.230489       290.506012    9.545057  10.393582  -521.728295
# 7             86.751438   41.304325           8.642761       267.267671   15.757501   5.830648  3714.219001
# ...

# %%
x=df.iloc[:, :-1].values
y=df.iloc[: ,1].values

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Split the dataset into features (X) and target (y)

# %%
X = df.drop(columns=["Sales"])  # Independent variables
y = df["Sales"]  # Dependent variable

# %% [markdown]
# # Split the data into training and testing sets (80% train, 20% test)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
poly = PolynomialFeatures(degree=2)

# %%
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)

# %%
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.fit_transform(x_test)

# %% [markdown]
# #  Initialize and train the Linear Regression model

# %%
model = LinearRegression()
model.fit(x_train_poly, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Make predictions on the test set

# %%
y_pred = model.predict(x_test_poly)

# %% [markdown]
# # Evaluating the model

# %%
mse = mean_squared_error(y_test, y_pred)  # Mean Squared Error
r2 = r2_score(y_test, y_pred)  # R-squared score

# %% [markdown]
# # Printing results

# %%
print("Mean Squared Error (MSE):", mse)
print("R-squared Score (R2):", r2)
# Out:
# Mean Squared Error (MSE): 12167.250373445095
# R-squared Score (R2): 0.9946320885756692

# %% [markdown]
# # SUMMARY

# %% [markdown]
# ### Advertising_Budget, Store_Size, Competitor_Stores, Customer_Income, Promotions, Month, and Sales, all of which have complete data. Summary statistics indicate significant variations in these factors, with Sales ranging widely, suggesting potential influences from store size, advertising budget, and promotions. Visualizations, including histograms and pairplots, reveal distributions of variables and possible relationships, highlighting trends such as the impact of marketing and customer income on sales performance.
